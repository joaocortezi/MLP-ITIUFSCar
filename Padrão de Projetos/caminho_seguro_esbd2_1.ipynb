# %%
class Navigator:
  # destiny : Point()
  # position : Point()
  # map : []
  # route : Route()

  def __init__(self, destiny, position):
    self.destiny = destiny
    self.position = position
    self.map = self.get_map() # updated: changed get_map() to self.get_map()
    self.route = Route(self.position, self.destiny)

  def get_map(self):
    # metodo que gerara mapa de pontos
    print("placeholder")

  # funcao para atualizar posicao atual
  def move_to(self, point): # updated: changed Point to point
    new_lat = point.latitude # updated: changed Point.latitude to point.latitude
    new_lon = point.longitude # updated: changed Point.longitude to point.longitude
    self.position = Point(new_lat, new_lon) # updated: changed [new_lat,new_lon] to Point(new_lat, new_lon)
    self.route = Route(self.position, self.destiny) # recalcula a rota

class Route:
  # route_points : []
  # safety_level : float

  def __init__(self, position, destiny):
    self.get_route(position, destiny) # updated: changed get_route() to self.get_route()
    self.safety_level = self.get_route() # updated: changed get_route() to self.get_route()

  def get_route(self, position, destiny, map):
    new_route = []
    # verifica pontos proximos dentro de map
    # para cada ponto proximo, verifica demais pontos ate o destino -> forma lista de pontos atraves do map
    # calcula nivel de seguranca para cada rota -> update_route_safety_level()
    # escolhe nova rota com maior seguranca -> new_route
    self.route_points = new_route

  def update_route_safety_level(self):
    # soma de point_safety_level de cada ponto da rota (self.route_points)
    # dividir a soma pela quantidade de pontos
    # retorna valor calculado
    print("placeholder")

class Point:
  # latitude : float
  # latitude : float
  # point_safety_level : SecurityLevel()

  def __init__(self, latitude, longitude):
    self.latitude = self.get_latitude(latitude) # updated: changed get_latitude() to self.get_latitude()
    self.longitude = self.get_longitude(longitude) # updated: changed get_longitude() to self.get_longitude()
    self.point_safety_level = SecurityLevel()

  def get_latitude(self, latitude):
    # valor de latitude obtido de meio externo
    print("placeholder")

  def get_longitude(self, longitude):
    # valor de longitude obtido de meio externo
    print("placeholder")    

class SecurityLevel:
  # security_level : float

  def __init__(self):
    self.security_level = self.create_security_level() # updated: changed create_secutiry_level() to self.create_security_level()

  def create_security_level(self):
    nota1 = self.verifica_obras(obras)
    nota2 = self.verifica_acidentes()
    nota3 = self.verifica_assaltos()
    nota4 = self.verifica_bairro()

    nota_final = SUM(nota1, nota2, nota3, nota4)/4
